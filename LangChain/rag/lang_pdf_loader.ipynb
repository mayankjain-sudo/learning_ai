# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
# !ls data

# %%
loader = PyPDFLoader("data/rh294.pdf")
pages = loader.load_and_split()
print(f"Number of pages: {len(pages)}")

# %%
#pages
pages[0].page_content
