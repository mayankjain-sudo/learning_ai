# %% [markdown]
# Batching in Chain, in this we can create a list of dict which we be use like single prompt

# %%
from langchain_ollama import OllamaLLM
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
prompt = ChatPromptTemplate.from_template("""
        You are helpful assistant.
        Answer the following question {question}
        """)

# %%
llm = OllamaLLM(model="llama3.2")

# %%
output_parser = StrOutputParser()

# %%
chain = prompt | llm | output_parser

# %%
questions = [
    {"question": "What is the capital of France?"},
    {"question": "Who is the president of the United States?"},
    {"question": "What is the largest mammal in the world?"},
]

# %%
response = chain.batch(questions)
response
# Out:
# ['The capital of France is Paris.',
#  'I can provide you with information that may change over time.\n\nAs of my cut-off knowledge date (01 March 2023), the President of the United States is:\n\nJoe Biden',
#  'The largest mammal in the world is the blue whale (Balaenoptera musculus). On average, an adult blue whale can grow up to 82 feet (25 meters) in length and weigh around 150-170 tons (136,000-152,000 kilograms). However, some individuals have been reported to reach lengths of over 100 feet (30 meters) and weigh up to 200 tons (181,000 kilograms). Blue whales are not only the largest mammals but also the largest animals to have ever existed on Earth.']

# %%
response[0]  # Response for first question
# Out:
# 'The capital of France is Paris.'
