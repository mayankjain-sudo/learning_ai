# %% [markdown]
# Chain streaming the output

# %%
from langchain_ollama import OllamaLLM
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
prompt = ChatPromptTemplate.from_template("""
        You are helpful assistant.
        Answer the following question {question}
        """)

# %%
llm = OllamaLLM(model="deepseek-r1:7b")

# %%
output_parser = StrOutputParser()

# %%
chain = prompt | llm | output_parser

# %%
for chunk in chain.stream({"question": "Tell me about the India?"}):
    print(chunk, end="", flush=True)
# Out:
# India is a vibrant and diverse nation nestled in South Asia, spanning over 1.3 billion people, making it one of the most populous countries in the world. Bordered by several countries including Pakistan, China, Nepal, Bhutan, and Bangladesh on land, and the Indian Ocean to the south, India's geographical diversity is notable.
#
# Culturally, India is a melting pot of traditions and identities, with significant contributions from Hinduism, Buddhism, Islam, and other religions. Its cuisine, known worldwide for dishes like biryani and curry, showcases this cultural tapestry. linguistically, the country is home to over 200 dialects across its diverse population.
#
# Economically, India's rapid growth has made it one of the fastest-growing economies globally, driven by a strong service sector and digital innovation, with companies like Infosys leading in software development. However, issues such as caste-based social hierarchies and gender disparities persist, highlighting ongoing challenges despite inclusive policies aimed at reducing inequality.
#
# Politically, India is a parliamentary democracy with major parties like the Bharatiya Janata Party (BJP) and the Indian National Congress leading governance. The Constitution governs the country, while regional tensions, notably in Jammu and Kashmir, remain a sensitive issue.
#
# Culturally, Bollywood has transcended borders, influencing global music, film, and fashion. Technologically, India is at the forefront of digital transformation, with significant innovation in areas like mobile banking and artificial intelligence.
#
# Despite its challenges, India's modernization efforts, including being a global financial hub and SEZs attracting foreign investment, position it as a dynamic and evolving nation. The interplay of natural phenomena like the monsoon adds to its unique cultural landscape.
#
# In summary, India is a complex and multifaceted country with rich diversity across culture, religion, language, economy, and politics, embodying a blend of tradition and modernity.
