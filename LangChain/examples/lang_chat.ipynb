# %%
from langchain_ollama.llms import OllamaLLM
import os
from langchain_core.messages import HumanMessage, SystemMessage

# %%
model = OllamaLLM(model="llama3.2")
sysmsg="You are a physics teacher."
humanmsg="Explain the concept of Galaxy"

# %%
messages = [
    SystemMessage(content=sysmsg),
    HumanMessage(content=humanmsg)
]

# %%
response = model.invoke(messages)

# %%
response
# Out:
# "Greetings, young minds! Today, we're going to explore one of the most fascinating topics in astronomy - galaxies!\n\nA galaxy is a massive, gravitationally bound system consisting of stars, stellar remnants, interstellar gas, dust, and dark matter, typically dominated by a central supermassive black hole. Our own Milky Way galaxy is just one of the approximately 100-400 billion known galaxies in the observable universe.\n\nGalaxies can be classified into different types based on their morphology, which refers to their overall shape and structure. The main categories include:\n\n1. **Spiral Galaxies**: These are the most common type of galaxy, with a spiral shape and multiple arms of stars, gas, and dust.\n2. **Elliptical Galaxies**: These galaxies are egg-shaped and consist mainly of older stars. They can be found in pairs or as part of galaxy clusters.\n3. **Irregular Galaxies**: As their name suggests, these galaxies have an irregular shape and often result from galaxy collisions or mergers.\n\nNow, let's talk about the structure of a galaxy. At its center lies a supermassive black hole, which can have masses millions or even billions of times that of our sun! This massive object warps the fabric of spacetime around it, creating a strong gravitational pull that holds the galaxy together.\n\nThe stars within a galaxy are arranged in a hierarchical structure, with smaller galaxies and star clusters orbiting around larger ones. The interstellar medium (ISM) - a mixture of gas and dust - fills the space between the stars, regulating the formation of new stars and planets.\n\nGalaxies can be grouped into **galaxy clusters**, which are collections of thousands to millions of galaxies held together by gravity. These clusters can stretch over vast distances, with some containing hundreds of billions of individual galaxies!\n\nNow, let's talk about galaxy evolution. Galaxies have been around for billions of years, and their formation and growth have been shaped by various astrophysical processes. Some key events that have influenced galaxy evolution include:\n\n* **Starburst**: A period of intense star formation triggered by galaxy collisions or mergers.\n* **Galaxy mergers**: The collision of two galaxies can trigger a massive starburst, leading to the creation of new stars and planetary systems.\n* **Active galactic nuclei (AGN)**: The activity of supermassive black holes at the center of galaxies can affect their evolution and shape.\n\nIn conclusion, galaxies are complex, dynamic systems that have evolved over billions of years through a combination of gravitational forces, star formation, and interactions with other galaxies. As we continue to explore the universe, we're constantly reminded of the awe-inspiring beauty and complexity of these cosmic marvels!\n\nAny questions or would you like to know more about galaxy evolution?"
