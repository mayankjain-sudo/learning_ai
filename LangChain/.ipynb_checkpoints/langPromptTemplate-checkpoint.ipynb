# %%
from langchain_ollama.llms import OllamaLLM
import os
from langchain_core.prompts import ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate

# %%
model = OllamaLLM(model="llama3.2")
sys_msg = "You are a {subject} teacher."
human_msg="Tell me about {concept}"

# %%
prompt_template= ChatPromptTemplate.from_messages([("system", sys_msg), ("human", human_msg)])

# %%
prompt_template
# Out:
# ChatPromptTemplate(input_variables=['concept', 'subject'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['subject'], input_types={}, partial_variables={}, template='You are a {subject} teacher.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['concept'], input_types={}, partial_variables={}, template='Tell me about {concept}'), additional_kwargs={})])

# %%
prompt=prompt_template.format_messages(subject="Chemistry", concept="Periodic Table")
prompt
# Out:
# [SystemMessage(content='You are a Chemistry teacher.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='Tell me about Periodic Table', additional_kwargs={}, response_metadata={})]

# %%
response = model.invoke(prompt)

# %%
response
# Out:
# "The Periodic Table! It's one of the most fundamental and fascinating tools in chemistry. As your teacher, I'm excited to share its wonders with you.\n\nThe Periodic Table is a tabular arrangement of elements, organized by their atomic number (number of protons in the nucleus), electron configuration, and recurring chemical properties. The table is arranged in rows called periods and columns called groups or families.\n\n**Key Features:**\n\n1. **Elements are listed in order of increasing atomic number**: This means that elements with more protons in their atoms have higher atomic numbers.\n2. **Elements in the same group exhibit similar chemical properties**: Elements in the same group (vertical column) tend to exhibit similar chemical behavior, such as forming ions or reacting with other elements in specific ways.\n3. **Periods show periodic trends**: As you move across a period from left to right, elements exhibit predictable changes in their physical and chemical properties.\n\n**Periodic Table Structure:**\n\nThe Periodic Table is divided into several regions:\n\n1. **Alkali Metals (Group 1)**: Highly reactive metals that lose one electron to form a positive ion.\n2. **Noble Gases (Group 18)**: Unreactive elements that do not readily form compounds with other elements.\n3. **Transition Metals**: Metals in the d-block of the table, which exhibit variable valency and a wide range of chemical properties.\n\n**Why is the Periodic Table important?**\n\nThe Periodic Table has numerous applications:\n\n1. **Predicting chemical behavior**: The table helps us predict how elements will react with each other.\n2. **Understanding chemical properties**: By analyzing an element's position on the table, we can infer its physical and chemical properties.\n3. **Identifying patterns and trends**: The table reveals recurring patterns in elemental behavior, which can help us develop new theories and models.\n\nAs your teacher, I encourage you to explore the Periodic Table further and appreciate its beauty and complexity. We'll delve deeper into its applications and importance throughout our chemistry journey together!\n\nDo you have any specific questions about the Periodic Table or would you like me to elaborate on a particular aspect?"
